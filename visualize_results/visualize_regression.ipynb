# %% [markdown]
# # Plotting Few-Shot Model Evaluation Results
#
# Assembling plots from summary files.

# %%
import os
import sys
import pandas as pd

# Setting up local details:
# This should be the location of the checkout of the FS-Mol repository:
FS_MOL_CHECKOUT_PATH = os.path.join(os.environ['HOME'], "FS-Mol-ADKT")
# This should be the location of the FS-Mol dataset:
FS_MOL_DATASET_PATH = os.path.join(os.environ['HOME'], "fs-mol-dataset")

os.chdir(FS_MOL_CHECKOUT_PATH)
sys.path.insert(0, FS_MOL_CHECKOUT_PATH)

from fs_mol.plotting.utils import (
    highlight_max_all, 
    plot_all_assays, 
    load_data,
    expand_values,
    plot_task_performances_by_id,
    box_plot,
    plot_by_size,
    get_aggregates_across_sizes,
    walltime_plot
)

# %% [markdown]
# ## Making summary files
#
# Summary files are obtained by running `fs_mol/plotting/collect_eval_runs.py` on the outputs of evaluation runs. If an evaluation output directory is "evaluation_output_directory" then summary files are created with:

# %% [raw]
# ! python fs_mol/plotting/collect_eval_runs.py {model_name} {evaluation_output_directory} --plot --metric r2

# %% [markdown]
# The option `--plot` results in a plot across support set sizes for each few-shot testing task. Final summarized results will be found in "evaluation_output_directory/summary/{model_name}_summary.csv"

# %% [markdown]
# ## Loading the collated evaluation data
#
# Create a dictionary of all model summary .csvs to be compared. The csvs are the final summaries from `collect_eval_runs.py`

# %%
# Configure this to contain all the models that you want to look at.
# Dict keys are human readable names, values are the path to the summary produced by collect_eval_runs.py
results_path = os.path.join(FS_MOL_CHECKOUT_PATH, "baselines")
output_path = os.path.join(FS_MOL_CHECKOUT_PATH, "visualize_results")

# a dictionary summarising all models to be compared. Add new paths here as desired.
model_summaries = {
    "ADKF-IFT": os.path.join(output_path, "ADKF-IFT/ADKF-IFT_regression_summary.csv"),
    "DKT": os.path.join(output_path, "DKT/DKT_regression_summary.csv"),
    "CNP": os.path.join(output_path, "CNP/CNP_regression_summary.csv"),
    "GP-ST": os.path.join(output_path, "GP-ST/GP-ST_regression_summary.csv"),
    "RF": os.path.join(output_path, "RF/RF_regression_summary.csv"),
    "GNN-MT": os.path.join(output_path, "GNN-MT/GNN-MT_regression_summary.csv"),
    "MAT": os.path.join(output_path, "MAT/MAT_regression_summary.csv"),
}
# Generated plots will be stored here, if you want to keep them. None disables saving.
plot_output_dir = os.path.join(output_path, "plots/regression")
all_tasks_output_dir = os.path.join(plot_output_dir, "all_tasks")
os.makedirs(plot_output_dir, exist_ok=True)
os.makedirs(all_tasks_output_dir, exist_ok=True)

# %% [markdown]
# # Configure this to contain all the models that you want to look at.
# # Dict keys are human readable names, values are the path to the summary produced by collect_eval_runs.py
# results_path = os.path.join(FS_MOL_CHECKOUT_PATH, "baselines")
# output_path = os.path.join(FS_MOL_CHECKOUT_PATH, "outputs")
#
# # a dictionary summarising all models to be compared. Add new paths here as desired.
# model_summaries = {
#     "ADKT": os.path.join(output_path, "FSMol_Eval_ADKTModel_2022-04-20_19-37-58/summary/ADKTNUMERIC_summary.csv"), # 2048
#     "DKT": os.path.join(output_path, "FSMol_Eval_DKTModel_2022-04-20_17-26-05/summary/DKTNUMERIC_summary.csv"), # 2048
#     "CNP": os.path.join(output_path, "FSMol_Eval_CNPModel_2022-04-20_19-09-11/summary/CNPNUMERIC_summary.csv"),
#     "GP-ST": os.path.join(output_path, "FSMol_Eval_GPST_2022-04-20_15-35-39/summary/GPSTNUMERIC_summary.csv"),
#     "RF": os.path.join(output_path, "FSMol_Eval_randomForestRegressor_2022-04-20_15-32-47/summary/RFR_summary.csv"),
#     "GNN-MT": os.path.join(output_path, "FSMol_Eval_Multitask_2022-04-20_19-39-13/summary/MULTITASKNUMERIC_summary.csv"),
#     "MAT": os.path.join(output_path, "FSMol_Eval_MAT_2022-04-20_15-38-38/summary/MATNUMERIC_summary.csv"),
# }
# # Generated plots will be stored here, if you want to keep them. None disables saving.
# plot_output_dir = os.path.join(output_path, "plots_numeric")
# all_tasks_output_dir = os.path.join(output_path, "plots_numeric/all_tasks")
# os.makedirs(plot_output_dir, exist_ok=True)
# os.makedirs(all_tasks_output_dir, exist_ok=True)

# %%
data = load_data(model_summaries, numeric=True)
# Out:
# Loading data for ADKF-IFT from /homes/wc337/FS-Mol-ADKT/visualize_results/ADKF-IFT/ADKF-IFT_regression_summary.csv.
# Loading data for DKT from /homes/wc337/FS-Mol-ADKT/visualize_results/DKT/DKT_regression_summary.csv.
# Loading data for CNP from /homes/wc337/FS-Mol-ADKT/visualize_results/CNP/CNP_regression_summary.csv.
# Loading data for GP-ST from /homes/wc337/FS-Mol-ADKT/visualize_results/GP-ST/GP-ST_regression_summary.csv.
# Loading data for RF from /homes/wc337/FS-Mol-ADKT/visualize_results/RF/RF_regression_summary.csv.
# Loading data for GNN-MT from /homes/wc337/FS-Mol-ADKT/visualize_results/GNN-MT/GNN-MT_regression_summary.csv.
# Loading data for MAT from /homes/wc337/FS-Mol-ADKT/visualize_results/MAT/MAT_regression_summary.csv.
# /homes/wc337/FS-Mol-ADKT/fs_mol/plotting/utils.py:560: FutureWarning: Dropping invalid columns in DataFrameGroupBy.mean is deprecated. In a future version, a TypeError will be raised. Before calling .mean, select only columns which should be valid for the function.
#   merged_df = merge_loaded_dfs(df_list, numeric=numeric)

# %% [markdown]
# ## Highlight the best result for each task

# %%
styled_df = data.style.apply(lambda row: highlight_max_all(row), axis=1)
# To save for exporting purposes, uncomment this (requires `pip install xlsxwriter`)
styled_df.to_excel(os.path.join(plot_output_dir, f"highlighted_comparison.xlsx"), engine='xlsxwriter')

styled_df
# Out:
# <style type="text/css">
# #T_69dd1_row0_col4, #T_69dd1_row0_col6, #T_69dd1_row0_col7, #T_69dd1_row0_col8, #T_69dd1_row1_col1, #T_69dd1_row1_col2, #T_69dd1_row1_col3, #T_69dd1_row1_col4, #T_69dd1_row1_col5, #T_69dd1_row2_col2, #T_69dd1_row2_col3, #T_69dd1_row2_col4, #T_69dd1_row2_col6, #T_69dd1_row3_col2, #T_69dd1_row3_col3, #T_69dd1_row3_col4, #T_69dd1_row3_col6, #T_69dd1_row4_col2, #T_69dd1_row4_col4, #T_69dd1_row4_col16, #T_69dd1_row4_col18, #T_69dd1_row4_col25, #T_69dd1_row5_col2, #T_69dd1_row5_col3, #T_69dd1_row5_col4, #T_69dd1_row5_col5, #T_69dd1_row5_col16, #T_69dd1_row6_col4, #T_69dd1_row6_col6, #T_69dd1_row6_col7, #T_69dd1_row6_col8, #T_69dd1_row7_col1, #T_69dd1_row7_col2, #T_69dd1_row7_col9, #T_69dd1_row7_col18, #T_69dd1_row8_col19, #T_69dd1_row8_col21, #T_69dd1_row8_col22, #T_69dd1_row8_col23, #T_69dd1_row9_col4, #T_69dd1_row9_col6, #T_69dd1_row9_col7, #T_69dd1_row9_col8, #T_69dd1_row10_col1, #T_69dd1_row10_col2, #T_69dd1_row10_col3, #T_69dd1_row10_col5, #T_69dd1_row10_col19, #T_69dd1_row11_col2, #T_69dd1_row11_col3, #T_69dd1_row11_col4, #T_69dd1_row11_col5, #T_69dd1_row11_col16, #T_69dd1_row12_col4, #T_69dd1_row12_col16, #T_69dd1_row12_col17, #T_69dd1_row12_col18, #T_69dd1_row12_col19, #T_69dd1_row12_col25, #T_69dd1_row13_col3, #T_69dd1_row13_col4, #T_69dd1_row13_col6, #T_69dd1_row13_col7, #T_69dd1_row13_col20, #T_69dd1_row14_col2, #T_69dd1_row14_col3, #T_69dd1_row14_col4, #T_69dd1_row14_col5, #T_69dd1_row14_col6, #T_69dd1_row15_col3, #T_69dd1_row15_col8, #T_69dd1_row15_col11, #T_69dd1_row15_col17, #T_69dd1_row15_col20, #T_69dd1_row15_col24, #T_69dd1_row16_col1, #T_69dd1_row16_col2, #T_69dd1_row16_col3, #T_69dd1_row16_col4, #T_69dd1_row17_col16, #T_69dd1_row17_col17, #T_69dd1_row17_col18, #T_69dd1_row17_col19, #T_69dd1_row18_col1, #T_69dd1_row18_col2, #T_69dd1_row18_col3, #T_69dd1_row18_col4, #T_69dd1_row18_col5, #T_69dd1_row18_col6, #T_69dd1_row19_col6, #T_69dd1_row19_col7, #T_69dd1_row19_col8, #T_69dd1_row19_col9, #T_69dd1_row20_col2, #T_69dd1_row20_col3, #T_69dd1_row20_col4, #T_69dd1_row20_col11, #T_69dd1_row21_col6, #T_69dd1_row21_col7, #T_69dd1_row21_col19, #T_69dd1_row21_col23, #T_69dd1_row22_col16, #T_69dd1_row22_col17, #T_69dd1_row22_col23, #T_69dd1_row22_col24, #T_69dd1_row23_col1, #T_69dd1_row23_col2, #T_69dd1_row23_col3, #T_69dd1_row23_col4, #T_69dd1_row23_col5, #T_69dd1_row24_col1, #T_69dd1_row24_col2, #T_69dd1_row24_col3, #T_69dd1_row24_col4, #T_69dd1_row24_col5, #T_69dd1_row25_col2, #T_69dd1_row25_col3, #T_69dd1_row25_col5, #T_69dd1_row25_col16, #T_69dd1_row25_col18, #T_69dd1_row25_col24, #T_69dd1_row26_col2, #T_69dd1_row26_col3, #T_69dd1_row26_col9, #T_69dd1_row26_col16, #T_69dd1_row27_col6, #T_69dd1_row27_col7, #T_69dd1_row27_col8, #T_69dd1_row27_col24, #T_69dd1_row28_col1, #T_69dd1_row28_col2, #T_69dd1_row28_col3, #T_69dd1_row28_col4, #T_69dd1_row28_col5, #T_69dd1_row29_col6, #T_69dd1_row29_col17, #T_69dd1_row29_col18, #T_69dd1_row29_col24, #T_69dd1_row30_col6, #T_69dd1_row30_col7, #T_69dd1_row30_col8, #T_69dd1_row30_col9, #T_69dd1_row31_col1, #T_69dd1_row31_col2, #T_69dd1_row31_col3, #T_69dd1_row31_col9, #T_69dd1_row31_col10, #T_69dd1_row32_col1, #T_69dd1_row32_col3, #T_69dd1_row32_col4, #T_69dd1_row32_col5, #T_69dd1_row32_col7, #T_69dd1_row33_col2, #T_69dd1_row33_col3, #T_69dd1_row33_col4, #T_69dd1_row33_col5, #T_69dd1_row33_col6, #T_69dd1_row34_col1, #T_69dd1_row34_col2, #T_69dd1_row34_col3, #T_69dd1_row34_col4, #T_69dd1_row34_col5, #T_69dd1_row35_col1, #T_69dd1_row35_col2, #T_69dd1_row35_col3, #T_69dd1_row35_col4, #T_69dd1_row35_col5, #T_69dd1_row36_col1, #T_69dd1_row36_col2, #T_69dd1_row36_col3, #T_69dd1_row36_col4, #T_69dd1_row36_col5, #T_69dd1_row36_col6, #T_69dd1_row37_col1, #T_69dd1_row37_col2, #T_69dd1_row37_col3, #T_69dd1_row37_col4, #T_69dd1_row37_col5, #T_69dd1_row38_col1, #T_69dd1_row38_col2, #T_69dd1_row38_col3, #T_69dd1_row38_col4, #T_69dd1_row38_col5, #T_69dd1_row39_col1, #T_69dd1_row39_col2, #T_69dd1_row39_col3, #T_69dd1_row39_col4, #T_69dd1_row39_col5, #T_69dd1_row40_col3, #T_69dd1_row40_col4, #T_69dd1_row ...

# %%
# expand out from val +/- error format, and calculate delta AUPRC
data = expand_values(data, model_summaries, numeric=True)

# %% [markdown]
# ## Performance Overview over all Tasks
#
# This compares with the trivial baseline of using a weighted coinflip according to the class imbalance in the training data.

# %%
# This uses Latex to render plots, and requires the type1ec and type1cm packages.
# It also required the dvipng utility.
# On Debian/Ubuntu-based systems, this can be installed using `apt install cm-super texlive-latex-extra dvipng`

#plot_task_performances_by_id(data, model_summaries, support_set_size = 16)

# %% [markdown]
# ### Incorporate protein information
#
# Our test tasks have associated target protein information available. We can merge this data to allow plotting with specific EC number classes highlighted.

# %%
protein_path = os.path.join(FS_MOL_CHECKOUT_PATH, "datasets/targets", "test_proteins.csv")
ecs = pd.read_csv(protein_path)
ecs["target_id"] = ecs["target_id"].astype(int).astype(str)
ecs["chembl_id"] = ecs["chembl_id"].astype(str)
ecs["TASK_ID"] = ecs.apply(lambda row: row["chembl_id"][6:], axis = 1)

data = ecs.merge(data, on="TASK_ID")

# %%
# the highlight class is the EC class that will be highlighted in the resulting plot. 
# You may wish to use this for comparison across different EC classes.
# plot_task_performances_by_id(data, model_summaries, support_set_size = 16, highlight_class = 2)

# %% [markdown]
# ## Plot for each task, comparing different models
#
# This makes an individual comparison plot over models for each few-shot testing task, across all support set sizes available.
#
# **Warning** Not to use lightly, it will take a few minutes to complete

# %%
# plot_all_assays(data, model_summaries.keys(), results_dir = all_tasks_output_dir)

# %% [markdown]
# # Summarise the overall performance in box plots
#
# This reproduces the model comparison box plots in the manuscript.

# %%
box_plot(data, model_summaries, support_set_size = 16, plot_output_dir=plot_output_dir, numeric=True)

# %%
box_plot(data, model_summaries, support_set_size = 32, plot_output_dir=plot_output_dir, numeric=True)

# %%
box_plot(data, model_summaries, support_set_size = 64, plot_output_dir=plot_output_dir, numeric=True)

# %%
box_plot(data, model_summaries, support_set_size = 128, plot_output_dir=plot_output_dir, numeric=True)

# %%
box_plot(data, model_summaries, support_set_size = 256, plot_output_dir=plot_output_dir, numeric=True)

# %% [markdown]
# ## Aggregate as a function of the number of training points, across all categories
#
# Here the results are aggregated according to EC class, and across all classes. This is used to plot the variation of performance with support set size, comparing all models in the model_summaries dictionary.

# %%
aggregate_df = get_aggregates_across_sizes(data, model_summaries, numeric=True)

# %%
# show results of Table 2 for support set size 16
cols = [x for x  in aggregate_df.columns if x.startswith("16")]
aggregate_df[cols]
# Out:
#              16_train (ADKF-IFT)  16_train (DKT)  16_train (CNP)  \
# EC_category
# 3                       0.177105        0.179895        0.013684
# 2                       0.174524        0.184902        0.109963
# 1                       0.043833        0.033667       -0.017167
# 4                       0.237000        0.261500        0.088000
# 5                       0.096000        0.067000       -0.016000
# 6                       0.063000        0.066000        0.000000
# all                     0.167315        0.175117        0.084090
#
#              16_train (GP-ST)  16_train (RF)  16_train (GNN-MT)  \
# EC_category
# 3                    0.126053       0.101316          -0.087211
# 2                    0.055366       0.045988          -0.046110
# 1                    0.020333      -0.010167          -0.146000
# 4                    0.251000       0.208500           0.009000
# 5                    0.008000       0.035000          -0.088000
# 6                   -0.007000      -0.008000          -0.219000
# all                  0.068108       0.054766          -0.059486
#
#              16_train (MAT)  16_train (ADKF-IFT) std  16_train (DKT) std  \
# EC_category
# 3                 -0.157000                 0.040758            0.044842
# 2                 -0.166854                 0.015202            0.015770
# 1                 -0.183667                 0.036251            0.034182
# 4                 -0.094000                 0.224000            0.247500
# 5                 -0.187000                 0.047000            0.061000
# 6                 -0.165000                 0.056000            0.069000
# all               -0.164928                 0.013921            0.014771
#
#              16_train (CNP) std  16_train (GP-ST) std  16_train (RF) std  \
# EC_category
# 3                      0.014039              0.039072           0.041858
# 2                      0.014883              0.013395           0.011713
# 1                      0.008455              0.017765           0.024676
# 4                      0.070000              0.254000           0.253500
# 5                      0.017000              0.017000           0.050000
# 6                      0.008000              0.068000           0.063000
# all                    0.012068              0.012860           0.012079
#
#              16_train (GNN-MT) std  16_train (MAT) std
# EC_category
# 3                         0.047956            0.049138
# 2                         0.018528            0.018835
# 1                         0.036233            0.041549
# 4                         0.243000            0.199000
# 5                         0.170000            0.129000
# 6                         0.262000            0.258000
# all                       0.016524            0.016507

# %%
cols = [x for x  in aggregate_df.columns if x.startswith("32")]
aggregate_df[cols]
# Out:
#              32_train (ADKF-IFT)  32_train (DKT)  32_train (CNP)  \
# EC_category
# 3                       0.251105        0.243895        0.013895
# 2                       0.266890        0.263098        0.119841
# 1                       0.087333        0.077000       -0.016333
# 4                       0.360500        0.362000        0.098500
# 5                       0.151000        0.137000       -0.010000
# 6                       0.181000        0.181000        0.001000
# all                     0.254351        0.249658        0.091721
#
#              32_train (GP-ST)  32_train (RF)  32_train (GNN-MT)  \
# EC_category
# 3                    0.201105       0.179895          -0.003000
# 2                    0.096524       0.096134           0.001573
# 1                    0.058667       0.043000          -0.127833
# 4                    0.343000       0.310500           0.157000
# 5                    0.057000       0.059000           0.029000
# 6                    0.063000       0.082000          -0.077000
# all                  0.116162       0.111000          -0.003865
#
#              32_train (MAT)  32_train (ADKF-IFT) std  32_train (DKT) std  \
# EC_category
# 3                 -0.045158                 0.054511            0.056223
# 2                 -0.099427                 0.019581            0.018907
# 1                 -0.106000                 0.058767            0.061869
# 4                  0.040500                 0.340500            0.349000
# 5                 -0.091000                 0.059000            0.095000
# 6                 -0.006000                 0.036000            0.030000
# all               -0.087054                 0.018364            0.018214
#
#              32_train (CNP) std  32_train (GP-ST) std  32_train (RF) std  \
# EC_category
# 3                      0.014749              0.052904           0.051076
# 2                      0.015694              0.017127           0.014945
# 1                      0.007632              0.049478           0.047331
# 4                      0.071500              0.360000           0.313500
# 5                      0.010000              0.076000           0.050000
# 6                      0.004000              0.070000           0.075000
# all                    0.012770              0.017018           0.015301
#
#              32_train (GNN-MT) std  32_train (MAT) std
# EC_category
# 3                         0.051796            0.044889
# 2                         0.021476            0.016032
# 1                         0.038210            0.032043
# 4                         0.391000            0.296500
# 5                         0.081000            0.176000
# 6                         0.139000            0.110000
# all                       0.019162            0.014843

# %%
cols = [x for x  in aggregate_df.columns if x.startswith("64")]
aggregate_df[cols]
# Out:
#              64_train (ADKF-IFT)  64_train (DKT)  64_train (CNP)  \
# EC_category
# 3                       0.310105        0.295316        0.013526
# 2                       0.363073        0.342841        0.126732
# 1                       0.116167        0.097833       -0.012333
# 4                       0.442000        0.440000        0.099500
# 5                       0.226000        0.209000       -0.012000
# 6                       0.279000        0.277000        0.002000
# all                     0.340090        0.321414        0.096973
#
#              64_train (GP-ST)  64_train (RF)  64_train (GNN-MT)  \
# EC_category
# 3                    0.266526       0.255684           0.064789
# 2                    0.161671       0.159537           0.075317
# 1                    0.102500       0.107833          -0.083667
# 4                    0.416500       0.418000           0.239500
# 5                    0.086000       0.125000           0.028000
# 6                    0.202000       0.182000          -0.016000
# all                  0.180694       0.177748           0.066631
#
#              64_train (MAT)  64_train (ADKF-IFT) std  64_train (DKT) std  \
# EC_category
# 3                  0.059263                 0.061811            0.063389
# 2                 -0.047220                 0.023738            0.022044
# 1                 -0.084833                 0.078616            0.077635
# 4                  0.237500                 0.403000            0.418000
# 5                 -0.058000                 0.063000            0.113000
# 6                  0.020000                 0.043000            0.035000
# all               -0.025387                 0.022091            0.021273
#
#              64_train (CNP) std  64_train (GP-ST) std  64_train (RF) std  \
# EC_category
# 3                      0.014773              0.060542           0.058459
# 2                      0.017310              0.021751           0.019258
# 1                      0.011090              0.076258           0.086958
# 4                      0.067500              0.415500           0.405000
# 5                      0.010000              0.082000           0.077000
# 6                      0.004000              0.079000           0.040000
# all                    0.013947              0.020721           0.019149
#
#              64_train (GNN-MT) std  64_train (MAT) std
# EC_category
# 3                         0.062106            0.051561
# 2                         0.023207            0.019717
# 1                         0.034253            0.020745
# 4                         0.426500            0.349500
# 5                         0.105000            0.113000
# 6                         0.084000            0.063000
# all                       0.021234            0.018294

# %%
cols = [x for x  in aggregate_df.columns if x.startswith("128")]
aggregate_df[cols]
# Out:
#              128_train (ADKF-IFT)  128_train (DKT)  128_train (CNP)  \
# EC_category
# 3                        0.366211         0.349368         0.010316
# 2                        0.400646         0.375720         0.057427
# 1                        0.156167         0.135833        -0.016333
# 4                        0.501000         0.496500         0.105000
# 5                        0.276000         0.296000        -0.011000
# 6                        0.364000         0.350000         0.004000
# all                      0.381892         0.359468         0.045135
#
#              128_train (GP-ST)  128_train (RF)  128_train (GNN-MT)  \
# EC_category
# 3                     0.324421        0.299211            0.146737
# 2                     0.208171        0.207610            0.018988
# 1                     0.145833        0.158333           -0.036000
# 4                     0.472000        0.461500            0.360000
# 5                     0.253000        0.195000            0.151000
# 6                     0.317000        0.229000            0.122000
# all                   0.230838        0.225279            0.046144
#
#              128_train (MAT)  128_train (ADKF-IFT) std  128_train (DKT) std  \
# EC_category
# 3                   0.097158                  0.070171             0.071692
# 2                  -0.108390                  0.030543             0.028853
# 1                  -0.075833                  0.091927             0.094620
# 4                   0.269500                  0.412000             0.433500
# 5                  -0.026000                  0.053000             0.067000
# 6                   0.073000                  0.044000             0.039000
# all                -0.062261                  0.026926             0.026068
#
#              128_train (CNP) std  128_train (GP-ST) std  128_train (RF) std  \
# EC_category
# 3                       0.015691               0.068567            0.062530
# 2                       0.025371               0.028110            0.026985
# 1                       0.010035               0.089407            0.094081
# 4                       0.064000               0.440000            0.422500
# 5                       0.009000               0.052000            0.051000
# 6                       0.004000               0.040000            0.047000
# all                     0.019071               0.025371            0.024055
#
#              128_train (GNN-MT) std  128_train (MAT) std
# EC_category
# 3                          0.062999             0.053254
# 2                          0.044708             0.044685
# 1                          0.047067             0.021465
# 4                          0.455000             0.364500
# 5                          0.043000             0.131000
# 6                          0.067000             0.127000
# all                        0.035768             0.035526

# %%
cols = [x for x  in aggregate_df.columns if x.startswith("256")]
aggregate_df[cols]
# Out:
#              256_train (ADKF-IFT)  256_train (DKT)  256_train (CNP)  \
# EC_category
# 3                        0.259714         0.231143        -0.029857
# 2                        0.555903         0.521806         0.141387
# 1                        0.074250         0.034000        -0.022250
# 4                             NaN              NaN              NaN
# 5                             NaN              NaN              NaN
# 6                        0.459000         0.442000         0.003000
# all                      0.460628         0.427256         0.095070
#
#              256_train (GP-ST)  256_train (RF)  256_train (GNN-MT)  \
# EC_category
# 3                     0.228000        0.222714            0.087000
# 2                     0.359419        0.345032            0.272258
# 1                     0.067750        0.063250           -0.050250
# 4                          NaN             NaN                 NaN
# 5                          NaN             NaN                 NaN
# 6                     0.430000        0.362000            0.229000
# all                   0.312535        0.299302            0.211093
#
#              256_train (MAT)  256_train (ADKF-IFT) std  256_train (DKT) std  \
# EC_category
# 3                   0.072857                  0.109271             0.112967
# 2                   0.100581                  0.039104             0.038159
# 1                  -0.035750                  0.027852             0.035835
# 4                        NaN                       NaN                  NaN
# 5                        NaN                       NaN                  NaN
# 6                   0.142000                  0.019000             0.024000
# all                 0.084349                  0.041391             0.041235
#
#              256_train (CNP) std  256_train (GP-ST) std  256_train (RF) std  \
# EC_category
# 3                       0.017143               0.113290            0.104265
# 2                       0.021444               0.034557            0.033918
# 1                       0.002955               0.028123            0.031410
# 4                            NaN                    NaN                 NaN
# 5                            NaN                    NaN                 NaN
# 6                       0.008000               0.029000            0.034000
# all                     0.019396               0.033533            0.032187
#
#              256_train (GNN-MT) std  256_train (MAT) std
# EC_category
# 3                          0.100901             0.081447
# 2                          0.033684             0.027373
# 1                          0.021742             0.021933
# 4                               NaN                  NaN
# 5                               NaN                  NaN
# 6                          0.070000             0.088000
# all                        0.033159             0.024127

# %%
# this function has the option to plot all classes separately.
plot_by_size(aggregate_df, model_summaries, plot_output_dir = plot_output_dir, numeric=True)

# %% [markdown]
# # Ranking
#
# Here we use [autorank](https://pypi.org/project/autorank/) for an appropriate comparison between all methods when evaluated on multiple tasks.

# %%
from autorank import autorank

# select correct data to rank with autorank
for size in [16, 32, 64, 128, 256]:

    df = data[[x for x in list(data.columns) if x.startswith(f"{size}") and "val" in x and "r2" in x]]
    result = autorank(df, verbose=False, alpha=0.1)
    print(result.rankdf["meanrank"])
    print()
# Out:
# 16_train (MAT) val r2         6.603604
# 16_train (GNN-MT) val r2      5.720721
# 16_train (RF) val r2          4.378378
# 16_train (GP-ST) val r2       3.702703
# 16_train (CNP) val r2         3.540541
# 16_train (DKT) val r2         2.045045
# 16_train (ADKF-IFT) val r2    2.009009
# Name: meanrank, dtype: float64
#
# 32_train (MAT) val r2         6.536036
# 32_train (GNN-MT) val r2      5.671171
# 32_train (RF) val r2          4.108108
# 32_train (CNP) val r2         4.085586
# 32_train (GP-ST) val r2       3.774775
# 32_train (DKT) val r2         2.009009
# 32_train (ADKF-IFT) val r2    1.815315
# Name: meanrank, dtype: float64
#
# 64_train (MAT) val r2         6.481982
# 64_train (GNN-MT) val r2      5.513514
# 64_train (CNP) val r2         4.554054
# 64_train (RF) val r2          3.936937
# 64_train (GP-ST) val r2       3.657658
# 64_train (DKT) val r2         2.216216
# 64_train (ADKF-IFT) val r2    1.639640
# Name: meanrank, dtype: float64
#
# 128_train (MAT) val r2         6.382883
# 128_train (GNN-MT) val r2      5.495495
# 128_train (CNP) val r2         5.270270
# 128_train (RF) val r2          3.549550
# 128_train (GP-ST) val r2       3.315315
# 128_train (DKT) val r2         2.270270
# 128_train (ADKF-IFT) val r2    1.716216
# Name: meanrank, dtype: float64
#
# 256_train (MAT) val r2         6.511628
# 256_train (CNP) val r2         5.860465
# 256_train (GNN-MT) val r2      5.232558
# 256_train (RF) val r2          3.534884
# 256_train (GP-ST) val r2       3.069767
# 256_train (DKT) val r2         2.430233
# 256_train (ADKF-IFT) val r2    1.360465
# Name: meanrank, dtype: float64

# %%
from scipy.stats import wilcoxon

# select correct data to rank with autorank
for size in [16, 32, 64, 128, 256]:

    df = data[[x for x in list(data.columns) if (x.startswith(f"{size}_train (ADKF-IFT)") or x.startswith(f"{size}_train (DKT)")) and "val" in x and "r2" in x]]
    df = df.dropna()
    diff = df.iloc[:,1] - df.iloc[:,0]
    diff = diff.to_numpy()
    print("number of tasks:", len(df))
    print("wilcoxon (two-sided):", wilcoxon(diff).pvalue)
    #print(create_report(result))
    print()
# Out:
# number of tasks: 111
# wilcoxon (two-sided): 0.08229650257920491
#
# number of tasks: 111
# wilcoxon (two-sided): 0.09573999670727207
#
# number of tasks: 111
# wilcoxon (two-sided): 3.737638206897399e-05
#
# number of tasks: 111
# wilcoxon (two-sided): 7.068818972169298e-05
#
# number of tasks: 43
# wilcoxon (two-sided): 9.809423349350156e-07

# %%
data["EC_super_class_name"].value_counts()
# Out:
# transferase       82
# hydrolase         19
# oxidoreductase     6
# lyase              2
# isomerase          1
# ligase             1
# Name: EC_super_class_name, dtype: int64
